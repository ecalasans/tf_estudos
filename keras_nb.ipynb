# %% [markdown]
# # Keras #

# %% [markdown]
# 1.  Keras Backend

# %%
#  Importação básica do Keras
from tensorflow.keras import backend as K
import tensorflow as tf

const = K.constant([[42, 21], [11, 99]], dtype=tf.float16, shape=[2,2])
const.numpy()
# Out:
# array([[42., 21.],
#        [11., 99.]], dtype=float16)

# %% [markdown]
# 2.  Keras Sequential Model(MNIST)

# %%
#  Conhecido dataset de números feitos à mão
mnist = tf.keras.datasets.mnist

# %% [markdown]
# Aqui dividimos o dataset em **conjunto de treino** e **conjunto de teste**

# %%
(train_x, train_y), (test_x, test_y) = mnist.load_data()

# %% [markdown]
# Estabelecemos o número de vezes que apresentaremos os dados
# ao modelo(`epochs`) e o tamanho do bloco de dados(`batch_size`)

# %%
epochs = 10
batch_size = 32

# %% [markdown]
# Normalizamos os dados em `x` para valores entre 0 e 1 e setamos
# o tipo para float32

# %%
train_x = tf.cast(train_x/255., tf.float32)
test_x = tf.cast(test_x/255., tf.float32)

# %% [markdown]
# Setamos os tipos em `y ` para int64

# %%
train_y = tf.cast(train_y, tf.int64)
test_y = tf.cast(test_y, tf.int64)

# %% [markdown]
# Modelo propriamente dito(maiores detalhes consultar livro na página
# 82 no Adobe Reader

# %%
model1 = tf.keras.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %% [markdown]
# Selecionar o otimizador da função de custo e compilar o modelo

# %%
optimiser = tf.keras.optimizers.Adam()
model1.compile(optimizer=optimiser, 
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

# %% [markdown]
# Treinar o modelo

# %%
model1.fit(x=train_x, y=train_y, batch_size=batch_size, epochs=epochs)
model1.summary()
# Out:
# Train on 60000 samples
# Epoch 1/10
#  - ETA: 4s - loss: 0.2568 - accuracy: 0.9248
# Epoch 2/10
# 60000/60000 [==============================] - 15s 245us/sample - loss: 0.0978 - accuracy: 0.9702
# Epoch 3/10
# 60000/60000 [==============================] - 14s 238us/sample - loss: 0.0674 - accuracy: 0.9787
# Epoch 4/10
# 60000/60000 [==============================] - 14s 227us/sample - loss: 0.0534 - accuracy: 0.9828
# Epoch 5/10
# 60000/60000 [==============================] - 13s 219us/sample - loss: 0.0435 - accuracy: 0.9858
# Epoch 6/10
# 60000/60000 [==============================] - 13s 212us/sample - loss: 0.0369 - accuracy: 0.9879
# Epoch 7/10
# 60000/60000 [==============================] - 12s 203us/sample - loss: 0.0295 - accuracy: 0.9901
# Epoch 8/10
# 60000/60000 [==============================] - 12s 199us/sample - loss: 0.0277 - accuracy: 0.9908
# Epoch 9/10
# 60000/60000 [==============================] - 12s 194us/sample - loss: 0.0244 - accuracy: 0.9918
# Epoch 10/10
# 60000/60000 [==============================] - 11s 189us/sample - loss: 0.0218 - accuracy: 0.9922
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  401920
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# dense_1 (Dense)              multiple                  5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Avaliar o modelo

# %%
model1.evaluate(test_x, test_y)
# Out:
# 10000/10000 [==============================] - 1s 133us/sample - loss: 0.0668 - accuracy: 0.9820
# [0.06684208440389339, 0.982]

# %% [markdown]
# ## API Funcional ##

# %% [markdown]
# Mesmo modelo anterior mas agora usando a API Funcional

# %%
inputs = tf.keras.Input(shape=(28,28))
x = tf.keras.layers.Flatten()(inputs)
x = tf.keras.layers.Dense(512, activation='relu', name='d1')(x)
x = tf.keras.layers.Dropout(0.2)(x)
predictions = tf.keras.layers.Dense(10, activation=tf.nn.softmax, name='d2')(x)

model3 = tf.keras.Model(inputs=inputs, outputs=predictions)

model3.compile(optimizer=optimiser, loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

model3.fit(train_x, train_y, batch_size=32, epochs=epochs)

model3.evaluate(test_x, test_y)
model3.summary()
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 13s 221us/sample - loss: 0.1819 - accuracy: 0.9442
# Epoch 2/10
# 60000/60000 [==============================] - 12s 207us/sample - loss: 0.0872 - accuracy: 0.9727
# Epoch 3/10
# 60000/60000 [==============================] - 12s 195us/sample - loss: 0.0611 - accuracy: 0.9807
# Epoch 4/10
# 60000/60000 [==============================] - 11s 190us/sample - loss: 0.0489 - accuracy: 0.9850
# Epoch 5/10
# 60000/60000 [==============================] - 11s 191us/sample - loss: 0.0424 - accuracy: 0.9859
# Epoch 6/10
# 60000/60000 [==============================] - 11s 189us/sample - loss: 0.0337 - accuracy: 0.9887
# Epoch 7/10
# 60000/60000 [==============================] - 11s 188us/sample - loss: 0.0274 - accuracy: 0.9911
# Epoch 8/10
# 60000/60000 [==============================] - 11s 187us/sample - loss: 0.0248 - accuracy: 0.9919
# Epoch 9/10
# 60000/60000 [==============================] - 11s 186us/sample - loss: 0.0228 - accuracy: 0.9926
# Epoch 10/10
# 60000/60000 [==============================] - 11s 187us/sample - loss: 0.0193 - accuracy: 0.9934
# 10000/10000 [==============================] - 1s 105us/sample - loss: 0.0697 - accuracy: 0.9830
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28)]          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# d1 (Dense)                   (None, 512)               401920
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# d2 (Dense)                   (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
